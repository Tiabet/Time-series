# %%
 # import tools for analyzing timeseries
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import scipy.stats as stats
# !pip install arch
import arch
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
# Out:
# Collecting arch
#   Downloading arch-6.1.0-cp39-cp39-win_amd64.whl (854 kB)
#      -------------------------------------- 854.9/854.9 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.5 in c:\anaconda\lib\site-packages (from arch) (1.9.1)
# Requirement already satisfied: numpy>=1.19 in c:\anaconda\lib\site-packages (from arch) (1.21.5)
# Requirement already satisfied: pandas>=1.1 in c:\anaconda\lib\site-packages (from arch) (2.0.2)
# Requirement already satisfied: statsmodels>=0.12 in c:\anaconda\lib\site-packages (from arch) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\lib\site-packages (from pandas>=1.1->arch) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda\lib\site-packages (from pandas>=1.1->arch) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas>=1.1->arch) (2022.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\anaconda\lib\site-packages (from statsmodels>=0.12->arch) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\anaconda\lib\site-packages (from statsmodels>=0.12->arch) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\anaconda\lib\site-packages (from packaging>=21.3->statsmodels>=0.12->arch) (3.0.9)
# Requirement already satisfied: six in c:\anaconda\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.12->arch) (1.16.0)
# Installing collected packages: arch
# Successfully installed arch-6.1.0

# %%
# !pip install -Iv rpy2==3.4.2
# Don't have to restart the runtime.
# Out:
# Using pip 22.2.2 from C:\Anaconda\lib\site-packages\pip (python 3.9)
# Collecting rpy2==3.4.2
#   Downloading rpy2-3.4.2.tar.gz (186 kB)
#      -------------------------------------- 186.1/186.1 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cffi>=1.10.0
#   Downloading cffi-1.15.1-cp39-cp39-win_amd64.whl (179 kB)
#      -------------------------------------- 179.1/179.1 kB 2.7 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.1/133.1 kB 7.7 MB/s eta 0:00:00
# Collecting pytz
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      -------------------------------------- 502.3/502.3 kB 7.9 MB/s eta 0:00:00
# Collecting tzlocal
#   Downloading tzlocal-5.0.1-py3-none-any.whl (20 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      -------------------------------------- 118.7/118.7 kB 7.2 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.3-cp39-cp39-win_amd64.whl (17 kB)
# Collecting tzdata
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Building wheels for collected packages: rpy2
#   Building wheel for rpy2 (setup.py): started
#   Building wheel for rpy2 (setup.py): finished with status 'done'
#   Created wheel for rpy2: filename=rpy2-3.4.2-py3-none-any.whl size=190479 sha256=7ed4874f6843d36640eb64fe429a2d9325a1555d747b6b119acd9c42820afc88
#   Stored in directory: c:\users\kkksk\appdata\local\pip\cache\wheels\e9\6e\27\f2a628f019da0b48ff5225f30943de87add4179f34d758a0d9
# Successfully built rpy2
# Installing collected packages: pytz, tzdata, pycparser, MarkupSafe, tzlocal, jinja2, cffi, rpy2
# Successfully installed MarkupSafe-2.1.3 cffi-1.15.1 jinja2-3.1.2 pycparser-2.21 pytz-2023.3 rpy2-3.4.2 tzdata-2023.3 tzlocal-5.0.1
#   Running command python setup.py egg_info
#   'sh'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#   배치 파일이 아닙니다.
#   C:\Users\kkksk\AppData\Local\Temp\pip-install-mr42v3eb\rpy2_df8ba27acac04d1892a666229cfbfaa9\setup.py:106: UserWarning: Command '('C:\\Program Files\\R\\R-4.2.2\\bin\\x64\\R', 'CMD', 'config', '--ldflags')' returned non-zero exit status 1.
#     warnings.warn(str(cpe))
#   'sh'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#   배치 파일이 아닙니다.
#   rpy2/_rinterface_cffi_build.py:268: UserWarning: Command '('C:\\Program Files\\R\\R-4.2.2\\bin\\x64\\R', 'CMD', 'config', '--ldflags')' returned non-zero exit status 1.
#     warnings.warn(str(e))
#   ['cffi>=1.10.0', 'jinja2', 'pytz', 'tzlocal']
#   running egg_info
#   creating C:\Users\kkksk\AppData\Local\Temp\pip-pip-egg-info-mjr0g1ny\rpy2.egg-info
#   writing C:\Users\kkksk\AppData\Local\Temp\pip-pip-egg-info-mjr0g1ny\rpy2.egg-info\PKG-INFO
#   writing dependency_links to C:\Users\kkksk\AppData\Local\Temp\pip-pip-egg-info-mjr0g1ny\rpy2.egg-info\dependency_links.txt
#   writing requirements to C:\Users\kkksk\AppData\Local\Temp\pip-pip-egg-info-mjr0g1ny\rpy2.egg-info\requires.txt
#   writing top-level names to C:\Users\kkksk\AppData\Local\Temp\pip-pip-egg-info-mjr0g1ny\rpy2.egg-info\top_level.txt
#   writing manifest file 'C:\Users\kkksk\AppData\Local\Temp\pip-pip-egg-info-mjr0g1ny\rpy2.egg-info\SOURCES.txt'
#   reading manifest file 'C:\Users\kkksk\AppData\Local\Temp\pip-pip-egg-info-mjr0g1ny\rpy2.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching 'README' anywhere in distribution
#   warning: no previously-included files matching '*patch*' found anywhere in distribution
#   warning: no previously-included files matching '*diff*' found anywhere in distribution
#   warning: no previously-included files matching '.hg' found anywhere in distribution
#   warning: no files found matching 'MANIFEST'
#   warning: no files found matching '_rinterface_cffi_build'
#   warning: no files found matching 'rpy\__init__.py'
#   warning: no files found matching 'rpy\situation.py'
#   warning: no files found matching '*.py' under directory 'rpy\robjects'
#   warning: no files found matching '*.py' under directory 'rpy\ipython'
#   warning: no files found matching '*.py' under directory 'rpy\interactive'
#   warning: no files found matching '*.py' under directory 'rpy\rlike'
#   no previously-included directories found matching 'dist'
#   warning: no files found matching 'doc\source\rpy2_logo.png'
#   adding license file 'AUTHORS'
#   writing manifest file 'C:\Users\kkksk\AppData\Local\Temp\pip-pip-egg-info-mjr0g1ny\rpy2.egg-info\SOURCES.txt'
#   Running command python setup.py bdist_wheel
#   'sh'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#   배치 파일이 아닙니다.
#   C:\Users\kkksk\AppData\Local\Temp\pip-install-mr42v3eb\rpy2_df8ba27acac04d1892a666229cfbfaa9\setup.py:106: UserWarning: Command '('C:\\Program Files\\R\\R-4.2.2\\bin\\x64\\R', 'CMD', 'config', '--ldflags')' returned non-zero exit status 1.
#     warnings.warn(str(cpe))
#   ['cffi>=1.10.0', 'jinja2', 'pytz', 'tzlocal']
#   'sh'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#   배치 파일이 아닙니다.
#   rpy2/_rinterface_cffi_build.py:268: UserWarning: Command '('C:\\Program Files\\R\\R-4.2.2\\bin\\x64\\R', 'CMD', 'config', '--ldflags')' returned non-zero exit status 1.
#     warnings.warn(str(e))
#   running bdist_wheel
#   running build
#   cffi mode: CFFI_MODE.ANY
#   running build_py
#   file _rinterface_cffi_abi.py (for module _rinterface_cffi_abi) not found
#   creating build
#   creating build\lib
#   creating build\lib\rpy2
#   copying .\rpy2\rinterface.py -> build\lib\rpy2
#   copying .\rpy2\situation.py -> build\lib\rpy2
#   copying .\rpy2\_rinterface_cffi_build.py -> build\lib\rpy2
#   copying .\rpy2\__init__.py -> build\lib\rpy2
#   creating build\lib\rpy2\rlike
#   copying .\rpy2\rlike\container.py -> build\lib\rpy2\rlike
#   copying .\rpy2\rlike\functional.py -> build\lib\rpy2\rlike
#   copying .\rpy2\rlike\indexing.py -> build\lib\rpy2\rlike
#   copying .\rpy2\rlike\__init__.py -> build\lib\rpy2\rlike
#   creating build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\bufferprotocol.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\callbacks.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\conversion.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\embedded.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\embedded_mswin.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\ffi_proxy.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\memorymanagement.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\na_values.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\openrlib.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\sexp.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\_rinterface_capi.py -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\__init__.py -> build\lib\rpy2\rinterface_lib
#   creating build\lib\rpy2\robjects
#   copying .\rpy2\robjects\constants.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\conversion.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\environments.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\functions.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\help.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\language.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\methods.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\numpy2ri.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\packages.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\packages_utils.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\pandas2ri.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\robject.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\vectors.py -> build\lib\rpy2\robjects
#   copying .\rpy2\robjects\__init__.py -> build\lib\rpy2\robjects
#   creating build\lib\rpy2\robjects\lib
#   copying .\rpy2\robjects\lib\dbplyr.py -> build\lib\rpy2\robjects\lib
#   copying .\rpy2\robjects\lib\dplyr.py -> build\lib\rpy2\robjects\lib
#   copying .\rpy2\robjects\lib\ggplot2.py -> build\lib\rpy2\robjects\lib
#   copying .\rpy2\robjects\lib\grdevices.py -> build\lib\rpy2\robjects\lib
#   copying .\rpy2\robjects\lib\grid.py -> build\lib\rpy2\robjects\lib
#   copying .\rpy2\robjects\lib\tidyr.py -> build\lib\rpy2\robjects\lib
#   copying .\rpy2\robjects\lib\__init__.py -> build\lib\rpy2\robjects\lib
#   creating build\lib\rpy2\interactive
#   copying .\rpy2\interactive\packages.py -> build\lib\rpy2\interactive
#   copying .\rpy2\interactive\process_revents.py -> build\lib\rpy2\interactive
#   copying .\rpy2\interactive\__init__.py -> build\lib\rpy2\interactive
#   creating build\lib\rpy2\ipython
#   copying .\rpy2\ipython\ggplot.py -> build\lib\rpy2\ipython
#   copying .\rpy2\ipython\html.py -> build\lib\rpy2\ipython
#   copying .\rpy2\ipython\rmagic.py -> build\lib\rpy2\ipython
#   copying .\rpy2\ipython\__init__.py -> build\lib\rpy2\ipython
#   creating build\lib\rpy2\tests
#   copying .\rpy2\tests\utils.py -> build\lib\rpy2\tests
#   copying .\rpy2\tests\__init__.py -> build\lib\rpy2\tests
#   creating build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_bufferprotocol.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_callbacks.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_embedded_r.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_endr.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_environment.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_externalptr.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_functions.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_memorymanagement.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_na.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_noinitialization.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_openrlib.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_sexp.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_symbol.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_threading.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vectors.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vector_bool.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vector_byte.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vector_complex.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vector_float.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vector_int.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vector_lang.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vector_list.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vector_numpy.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vector_pairlist.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\test_vector_str.py -> build\lib\rpy2\tests\rinterface
#   copying .\rpy2\tests\rinterface\__init__.py -> build\lib\rpy2\tests\rinterface
#   creating build\lib\rpy2\tests\rlike
#   copying .\rpy2\tests\rlike\test_container.py -> build\lib\rpy2\tests\rlike
#   copying .\rpy2\tests\rlike\test_functional.py -> build\lib\rpy2\tests\rlike
#   copying .\rpy2\tests\rlike\test_indexing.py -> build\lib\rpy2\tests\rlike
#   creating build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_array.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_conversion.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_conversion_numpy.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_dataframe.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_environment.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_formula.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_function.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_help.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_language.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_methods.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_packages.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_packages_utils.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_pandas_conversions.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_robjects.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_rs4.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_serialization.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_translated_function.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_vector.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_vector_datetime.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_vector_extractdelegator.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\test_vector_factor.py -> build\lib\rpy2\tests\robjects
#   copying .\rpy2\tests\robjects\__init__.py -> build\lib\rpy2\tests\robjects
#   creating build\lib\rpy2\tests\ipython
#   copying .\rpy2\tests\ipython\test_ggplot.py -> build\lib\rpy2\tests\ipython
#   copying .\rpy2\tests\ipython\test_html.py -> build\lib\rpy2\tests\ipython
#   copying .\rpy2\tests\ipython\test_rmagic.py -> build\lib\rpy2\tests\ipython
#   copying .\rpy2\tests\ipython\__init__.py -> build\lib\rpy2\tests\ipython
#   creating build\lib\rpy2\tests\robjects\lib
#   copying .\rpy2\tests\robjects\lib\test_dbplyr.py -> build\lib\rpy2\tests\robjects\lib
#   copying .\rpy2\tests\robjects\lib\test_dplyr.py -> build\lib\rpy2\tests\robjects\lib
#   copying .\rpy2\tests\robjects\lib\test_ggplot2.py -> build\lib\rpy2\tests\robjects\lib
#   copying .\rpy2\tests\robjects\lib\test_grdevices.py -> build\lib\rpy2\tests\robjects\lib
#   copying .\rpy2\tests\robjects\lib\test_grid.py -> build\lib\rpy2\tests\robjects\lib
#   copying .\rpy2\tests\robjects\lib\test_tidyr.py -> build\lib\rpy2\tests\robjects\lib
#   copying .\rpy2\tests\robjects\lib\__init__.py -> build\lib\rpy2\tests\robjects\lib
#   copying .\rpy2\rinterface_lib\R_API.h -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\R_API_eventloop.h -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\R_API_eventloop.c -> build\lib\rpy2\rinterface_lib
#   copying .\rpy2\rinterface_lib\RPY2.h -> build\lib\rpy2\rinterface_lib
#   file _rinterface_cffi_abi.py (for module _rinterface_cffi_abi) not found
#   generating cffi module 'build\\lib\\_rinterface_cffi_abi.py'
#   C:\Anaconda\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   ---
#   CFFI_MODE.ANY
#   ABI mode interface built.
#   API mode interface not built because: COMPILATION_STATUS.RFLAGS_ERROR
#   To change the API/ABI build mode, set or modify the environment variable RPY2_CFFI_MODE.
#   installing to build\bdist.win-amd64\wheel
#   running install
#   running install_lib
#   creating build\bdist.win-amd64
#   creating build\bdist.win-amd64\wheel
#   creating build\bdist.win-amd64\wheel\rpy2
#   creating build\bdist.win-amd64\wheel\rpy2\interactive
#   copying build\lib\rpy2\interactive\packages.py -> build\bdist.win-amd64\wheel\.\rpy2\interactive
#   copying build\lib\rpy2\interactive\process_revents.py -> build\bdist.win-amd64\wheel\.\rpy2\interactive
#   copying build\lib\rpy2\interactive\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\interactive
#   creating build\bdist.win-amd64\wheel\rpy2\ipython
#   copying build\lib\rpy2\ipython\ggplot.py -> build\bdist.win-amd64\wheel\.\rpy2\ipython
#   copying build\lib\rpy2\ipython\html.py -> build\bdist.win-amd64\wheel\.\rpy2\ipython
#   copying build\lib\rpy2\ipython\rmagic.py -> build\bdist.win-amd64\wheel\.\rpy2\ipython
#   copying build\lib\rpy2\ipython\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\ipython
#   copying build\lib\rpy2\rinterface.py -> build\bdist.win-amd64\wheel\.\rpy2
#   creating build\bdist.win-amd64\wheel\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\bufferprotocol.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\callbacks.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\conversion.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\embedded.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\embedded_mswin.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\ffi_proxy.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\memorymanagement.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\na_values.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\openrlib.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\RPY2.h -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\R_API.h -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\R_API_eventloop.c -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\R_API_eventloop.h -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\sexp.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\_rinterface_capi.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   copying build\lib\rpy2\rinterface_lib\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\rinterface_lib
#   creating build\bdist.win-amd64\wheel\rpy2\rlike
#   copying build\lib\rpy2\rlike\container.py -> build\bdist.win-amd64\wheel\.\rpy2\rlike
#   copying build\lib\rpy2\rlike\functional.py -> build\bdist.win-amd64\wheel\.\rpy2\rlike
#   copying build\lib\rpy2\rlike\indexing.py -> build\bdist.win-amd64\wheel\.\rpy2\rlike
#   copying build\lib\rpy2\rlike\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\rlike
#   creating build\bdist.win-amd64\wheel\rpy2\robjects
#   copying build\lib\rpy2\robjects\constants.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\conversion.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\environments.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\functions.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\help.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\language.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   creating build\bdist.win-amd64\wheel\rpy2\robjects\lib
#   copying build\lib\rpy2\robjects\lib\dbplyr.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects\lib
#   copying build\lib\rpy2\robjects\lib\dplyr.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects\lib
#   copying build\lib\rpy2\robjects\lib\ggplot2.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects\lib
#   copying build\lib\rpy2\robjects\lib\grdevices.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects\lib
#   copying build\lib\rpy2\robjects\lib\grid.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects\lib
#   copying build\lib\rpy2\robjects\lib\tidyr.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects\lib
#   copying build\lib\rpy2\robjects\lib\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects\lib
#   copying build\lib\rpy2\robjects\methods.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\numpy2ri.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\packages.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\packages_utils.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\pandas2ri.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\robject.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\vectors.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\robjects\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\robjects
#   copying build\lib\rpy2\situation.py -> build\bdist.win-amd64\wheel\.\rpy2
#   creating build\bdist.win-amd64\wheel\rpy2\tests
#   creating build\bdist.win-amd64\wheel\rpy2\tests\ipython
#   copying build\lib\rpy2\tests\ipython\test_ggplot.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\ipython
#   copying build\lib\rpy2\tests\ipython\test_html.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\ipython
#   copying build\lib\rpy2\tests\ipython\test_rmagic.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\ipython
#   copying build\lib\rpy2\tests\ipython\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\ipython
#   creating build\bdist.win-amd64\wheel\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_bufferprotocol.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_callbacks.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_embedded_r.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_endr.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_environment.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_externalptr.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_functions.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_memorymanagement.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_na.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_noinitialization.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_openrlib.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_sexp.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_symbol.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_threading.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vectors.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vector_bool.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vector_byte.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vector_complex.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vector_float.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vector_int.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vector_lang.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vector_list.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vector_numpy.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vector_pairlist.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\test_vector_str.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   copying build\lib\rpy2\tests\rinterface\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rinterface
#   creating build\bdist.win-amd64\wheel\rpy2\tests\rlike
#   copying build\lib\rpy2\tests\rlike\test_container.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rlike
#   copying build\lib\rpy2\tests\rlike\test_functional.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rlike
#   copying build\lib\rpy2\tests\rlike\test_indexing.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\rlike
#   creating build\bdist.win-amd64\wheel\rpy2\tests\robjects
#   creating build\bdist.win-amd64\wheel\rpy2\tests\robjects\lib
#   copying build\lib\rpy2\tests\robjects\lib\test_dbplyr.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects\lib
#   copying build\lib\rpy2\tests\robjects\lib\test_dplyr.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects\lib
#   copying build\lib\rpy2\tests\robjects\lib\test_ggplot2.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects\lib
#   copying build\lib\rpy2\tests\robjects\lib\test_grdevices.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects\lib
#   copying build\lib\rpy2\tests\robjects\lib\test_grid.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects\lib
#   copying build\lib\rpy2\tests\robjects\lib\test_tidyr.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects\lib
#   copying build\lib\rpy2\tests\robjects\lib\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects\lib
#   copying build\lib\rpy2\tests\robjects\test_array.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_conversion.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_conversion_numpy.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_dataframe.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_environment.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_formula.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_function.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_help.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_language.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_methods.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_packages.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_packages_utils.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_pandas_conversions.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_robjects.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_rs4.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_serialization.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_translated_function.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_vector.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_vector_datetime.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_vector_extractdelegator.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\test_vector_factor.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\robjects\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\tests\robjects
#   copying build\lib\rpy2\tests\utils.py -> build\bdist.win-amd64\wheel\.\rpy2\tests
#   copying build\lib\rpy2\tests\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2\tests
#   copying build\lib\rpy2\_rinterface_cffi_build.py -> build\bdist.win-amd64\wheel\.\rpy2
#   copying build\lib\rpy2\__init__.py -> build\bdist.win-amd64\wheel\.\rpy2
#   copying build\lib\_rinterface_cffi_abi.py -> build\bdist.win-amd64\wheel\.
#   running install_egg_info
#   running egg_info
#   writing rpy2.egg-info\PKG-INFO
#   writing dependency_links to rpy2.egg-info\dependency_links.txt
#   writing requirements to rpy2.egg-info\requires.txt
#   writing top-level names to rpy2.egg-info\top_level.txt
#   reading manifest file 'rpy2.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching 'README' anywhere in distribution
#   warning: no previously-included files matching '*patch*' found anywhere in distribution
#   warning: no previously-included files matching '*diff*' found anywhere in distribution
#   warning: no previously-included files matching '.hg' found anywhere in distribution
#   warning: no files found matching 'MANIFEST'
#   warning: no files found matching '_rinterface_cffi_build'
#   warning: no files found matching 'rpy\__init__.py'
#   warning: no files found matching 'rpy\situation.py'
#   warning: no files found matching '*.py' under directory 'rpy\robjects'
#   warning: no files found matching '*.py' under directory 'rpy\ipython'
#   warning: no files found matching '*.py' under directory 'rpy\interactive'
#   warning: no files found matching '*.py' under directory 'rpy\rlike'
#   no previously-included directories found matching 'dist'
#   warning: no files found matching 'doc\source\rpy2_logo.png'
#   adding license file 'AUTHORS'
#   writing manifest file 'rpy2.egg-info\SOURCES.txt'
#   Copying rpy2.egg-info to build\bdist.win-amd64\wheel\.\rpy2-3.4.2-py3.9.egg-info
#   running install_scripts
#   adding license file "AUTHORS" (matched pattern "AUTHORS*")
#   creating build\bdist.win-amd64\wheel\rpy2-3.4.2.dist-info\WHEEL
#   creating 'C:\Users\kkksk\AppData\Local\Temp\pip-wheel-iw1e4qid\rpy2-3.4.2-py3-none-any.whl' and adding 'build\bdist.win-amd64\wheel' to it
#   adding '_rinterface_cffi_abi.py'
#   adding 'rpy2/__init__.py'
#   adding 'rpy2/_rinterface_cffi_build.py'
#   adding 'rpy2/rinterface.py'
#   adding 'rpy2/situation.py'
#   adding 'rpy2/interactive/__init__.py'
#   adding 'rpy2/interactive/packages.py'
#   adding 'rpy2/interactive/process_revents.py'
#   adding 'rpy2/ipython/__init__.py'
#   adding 'rpy2/ipython/ggplot.py'
#   adding 'rpy2/ipython/html.py'
#   adding 'rpy2/ipython/rmagic.py'
#   adding 'rpy2/rinterface_lib/RPY2.h'
#   adding 'rpy2/rinterface_lib/R_API.h'
#   adding 'rpy2/rinterface_lib/R_API_eventloop.c'
#   adding 'rpy2/rinterface_lib/R_API_eventloop.h'
#   adding 'rpy2/rinterface_lib/__init__.py'
#   adding 'rpy2/rinterface_lib/_rinterface_capi.py'
#   adding 'rpy2/rinterface_lib/bufferprotocol.py'
#   adding 'rpy2/rinterface_lib/callbacks.py'
#   adding 'rpy2/rinterface_lib/conversion.py'
#   adding 'rpy2/rinterface_lib/embedded.py'
#   adding 'rpy2/rinterface_lib/embedded_mswin.py'
#   adding 'rpy2/rinterface_lib/ffi_proxy.py'
#   adding 'rpy2/rinterface_lib/memorymanagement.py'
#   adding 'rpy2/rinterface_lib/na_values.py'
#   adding 'rpy2/rinterface_lib/openrlib.py'
#   adding 'rpy2/rinterface_lib/sexp.py'
#   adding 'rpy2/rlike/__init__.py'
#   adding 'rpy2/rlike/container.py'
#   adding 'rpy2/rlike/functional.py'
#   adding 'rpy2/rlike/indexing.py'
#   adding 'rpy2/robjects/__init__.py'
#   adding 'rpy2/robjects/constants.py'
#   adding 'rpy2/robjects/conversion.py'
#   adding 'rpy2/robjects/environments.py'
#   adding 'rpy2/robjects/functions.py'
#   adding 'rpy2/robjects/help.py'
#   adding 'rpy2/robjects/language.py'
#   adding 'rpy2/robjects/methods.py'
#   adding 'rpy2/robjects/numpy2ri.py'
#   adding 'rpy2/robjects/packages.py'
#   adding 'rpy2/robjects/packages_utils.py'
#   adding 'rpy2/robjects/pandas2ri.py'
#   adding 'rpy2/robjects/robject.py'
#   adding 'rpy2/robjects/vectors.py'
#   adding 'rpy2/robjects/lib/__init__.py'
#   adding 'rpy2/robjects/lib/dbplyr.py'
#   adding 'rpy2/robjects/lib/dplyr.py'
#   adding 'rpy2/robjects/lib/ggplot2.py'
#   adding 'rpy2/robjects/lib/grdevices.py'
#   adding 'rpy2/robjects/lib/grid.py'
#   adding 'rpy2/robjects/lib/tidyr.py'
#   adding 'rpy2/tests/__init__.py'
#   adding 'rpy2/tests/utils.py'
#   adding 'rpy2/tests/ipython/__init__.py'
#   adding 'rpy2/tests/ipython/test_ggplot.py'
#   adding 'rpy2/tests/ipython/test_html.py'
#   adding 'rpy2/tests/ipython/test_rmagic.py'
#   adding 'rpy2/tests/rinterface/__init__.py'
#   adding 'rpy2/tests/rinterface/test_bufferprotocol.py'
#   adding 'rpy2/tests/rinterface/test_callbacks.py'
#   adding 'rpy2/tests/rinterface/test_embedded_r.py'
#   adding 'rpy2/tests/rinterface/test_endr.py'
#   adding 'rpy2/tests/rinterface/test_environment.py'
#   adding 'rpy2/tests/rinterface/test_externalptr.py'
#   adding 'rpy2/tests/rinterface/test_functions.py'
#   adding 'rpy2/tests/rinterface/test_memorymanagement.py'
#   adding 'rpy2/tests/rinterface/test_na.py'
#   adding 'rpy2/tests/rinterface/test_noinitialization.py'
#   adding 'rpy2/tests/rinterface/test_openrlib.py'
#   adding 'rpy2/tests/rinterface/test_sexp.py'
#   adding 'rpy2/tests/rinterface/test_symbol.py'
#   adding 'rpy2/tests/rinterface/test_threading.py'
#   adding 'rpy2/tests/rinterface/test_vector_bool.py'
#   adding 'rpy2/tests/rinterface/test_vector_byte.py'
#   adding 'rpy2/tests/rinterface/test_vector_complex.py'
#   adding 'rpy2/tests/rinterface/test_vector_float.py'
#   adding 'rpy2/tests/rinterface/test_vector_int.py'
#   adding 'rpy2/tests/rinterface/test_vector_lang.py'
#   adding 'rpy2/tests/rinterface/test_vector_list.py'
#   adding 'rpy2/tests/rinterface/test_vector_numpy.py'
#   adding 'rpy2/tests/rinterface/test_vector_pairlist.py'
#   adding 'rpy2/tests/rinterface/test_vector_str.py'
#   adding 'rpy2/tests/rinterface/test_vectors.py'
#   adding 'rpy2/tests/rlike/test_container.py'
#   adding 'rpy2/tests/rlike/test_functional.py'
#   adding 'rpy2/tests/rlike/test_indexing.py'
#   adding 'rpy2/tests/robjects/__init__.py'
#   adding 'rpy2/tests/robjects/test_array.py'
#   adding 'rpy2/tests/robjects/test_conversion.py'
#   adding 'rpy2/tests/robjects/test_conversion_numpy.py'
#   adding 'rpy2/tests/robjects/test_dataframe.py'
#   adding 'rpy2/tests/robjects/test_environment.py'
#   adding 'rpy2/tests/robjects/test_formula.py'
#   adding 'rpy2/tests/robjects/test_function.py'
#   adding 'rpy2/tests/robjects/test_help.py'
#   adding 'rpy2/tests/robjects/test_language.py'
#   adding 'rpy2/tests/robjects/test_methods.py'
#   adding 'rpy2/tests/robjects/test_packages.py'
#   adding 'rpy2/tests/robjects/test_packages_utils.py'
#   adding 'rpy2/tests/robjects/test_pandas_conversions.py'
#   adding 'rpy2/tests/robjects/test_robjects.py'
#   adding 'rpy2/tests/robjects/test_rs4.py'
#   adding 'rpy2/tests/robjects/test_serialization.py'
#   adding 'rpy2/tests/robjects/test_translated_function.py'
#   adding 'rpy2/tests/robjects/test_vector.py'
#   adding 'rpy2/tests/robjects/test_vector_datetime.py'
#   adding 'rpy2/tests/robjects/test_vector_extractdelegator.py'
#   adding 'rpy2/tests/robjects/test_vector_factor.py'
#   adding 'rpy2/tests/robjects/lib/__init__.py'
#   adding 'rpy2/tests/robjects/lib/test_dbplyr.py'
#   adding 'rpy2/tests/robjects/lib/test_dplyr.py'
#   adding 'rpy2/tests/robjects/lib/test_ggplot2.py'
#   adding 'rpy2/tests/robjects/lib/test_grdevices.py'
#   adding 'rpy2/tests/robjects/lib/test_grid.py'
#   adding 'rpy2/tests/robjects/lib/test_tidyr.py'
#   adding 'rpy2-3.4.2.dist-info/AUTHORS'
#   adding 'rpy2-3.4.2.dist-info/METADATA'
#   adding 'rpy2-3.4.2.dist-info/WHEEL'
#   adding 'rpy2-3.4.2.dist-info/top_level.txt'
#   adding 'rpy2-3.4.2.dist-info/RECORD'
#   removing build\bdist.win-amd64\wheel
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# ydata-profiling 4.1.0 requires pandas!=1.4.0,<1.6,>1.1, but you have pandas 2.0.2 which is incompatible.
# distributed 2022.7.0 requires dask==2022.7.0, but you have dask 2023.5.1 which is incompatible.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.

# %%
weekly_oil = pd.read_excel('TAF_3_Modelling_Volatility_PES_oil.xls', index_col=0)
weekly_oil.index = pd.to_datetime(weekly_oil.index)
weekly_oil.index.freq = 'W-FRI'

# %%
f, axes = plt.subplots(nrows=3, ncols=1, figsize=(9, 3*3))
axes[0].plot(weekly_oil,color='black',linewidth=1,label='Weekly oil spot price')
axes[0].legend()
axes[1].plot(weekly_oil.diff(),color='black',linewidth=1,label='First-difference of the price')
axes[1].legend()
axes[2].plot(np.log(weekly_oil/weekly_oil.shift(1))*100,color='black',linewidth=1,label='The logarithmic change in the price')
axes[2].legend()
plt.show()

# %%
def adf_test(dataframe):
    result = adfuller(dataframe)
    print(f'Statistics: {result[0]}')
    print(f'p-value: {result[1]}')
    print(f'Critical values: {result[4]}')
adf_test(weekly_oil)
print('---'*40)
adf_test(weekly_oil.diff().dropna())
print('---'*40)
adf_test(np.log(weekly_oil/weekly_oil.shift(1)).dropna()*100)
# Out:
# Statistics: -1.1354866114313116
# p-value: 0.7007148498766302
# Critical values: {'1%': -3.4351321860409674, '5%': -2.863651979448174, '10%': -2.567894416324791}
# ------------------------------------------------------------------------------------------------------------------------
# Statistics: -9.970477287647242
# p-value: 2.24737354362305e-17
# Critical values: {'1%': -3.4351321860409674, '5%': -2.863651979448174, '10%': -2.567894416324791}
# ------------------------------------------------------------------------------------------------------------------------
# Statistics: -17.180926385469377
# p-value: 6.647698576457701e-30
# Critical values: {'1%': -3.4351078301822016, '5%': -2.8636412316027577, '10%': -2.5678886927682663}

# %%
def kpss_test(dataframe):
    result = kpss(dataframe)
    print(f'Statistics: {result[0]}')
    print(f'bounded p-value: {result[1]}')
    print(f'Critical values: {result[3]}')
kpss_test(weekly_oil)
print('---'*40)
kpss_test(weekly_oil.diff().dropna())
print('---'*40)
kpss_test(np.log(weekly_oil/weekly_oil.shift(1)).dropna()*100)
# Out:
# Statistics: 4.850221989568525
# bounded p-value: 0.01
# Critical values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# ------------------------------------------------------------------------------------------------------------------------
# Statistics: 0.08440189249882568
# bounded p-value: 0.1
# Critical values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# ------------------------------------------------------------------------------------------------------------------------
# Statistics: 0.07035420343048165
# bounded p-value: 0.1
# Critical values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# C:\Anaconda\lib\site-packages\statsmodels\tsa\stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# C:\Anaconda\lib\site-packages\statsmodels\tsa\stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Anaconda\lib\site-packages\statsmodels\tsa\stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
log_change = np.log(weekly_oil/weekly_oil.shift(1)).dropna() * 100
f, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 2*4))
plot_acf(log_change, lags=12, ax=axes[0], title='Autocorrelations', color='black',
         vlines_kwargs={'colors': 'black', 'linewidth': 5}, alpha=None)
plot_pacf(log_change, lags=12, ax=axes[1], method='ols', title='PACF', color='gray',
          vlines_kwargs={'colors': 'gray', 'linewidth': 5}, alpha=None)
axes[1].hlines(xmin=0, xmax=12, y=2*np.sqrt(1/len(log_change)),
               label='two standard deviations from zero', color='black', linewidth=1)
axes[1].hlines(xmin=0, xmax=12, y=-2*np.sqrt(1/len(log_change)), color='black', linewidth=1)
axes[1].legend()
plt.tight_layout()
plt.show()

# %%
res_1 = ARIMA(endog=log_change, order=(0, 0, [1, 3]), trend='c').fit(method='innovations_mle')
print('MA([1,3])')
for param_name, param in zip(res_1.params.index, res_1.params):
    coef = round(param, 2)
    t_stats = round(res_1.tvalues[param_name], 2)
    print(f'[{param_name}] = coef:{coef}, t_stats:{t_stats}')
residuals = res_1.resid
acf_d = acf(residuals, nlags=8)[1:]
print('ACF of the residuals')
print(acf_d)
squared_resids = residuals**2
acf_d_2 = acf(squared_resids, nlags=8)[1:]
print('ACF of the squared residuals')
print(acf_d_2)
# Out:
# MA([1,3])
# [const] = coef:0.13, t_stats:0.9
# [ma.L1] = coef:0.18, t_stats:9.31
# [ma.L3] = coef:0.09, t_stats:4.6
# [sigma2] = coef:16.98, t_stats:41.3
# ACF of the residuals
# [ 0.00189867  0.01249435 -0.00166611 -0.00924516 -0.0133628  -0.00787883
#   0.01006452  0.00517871]
# ACF of the squared residuals
# [0.18257965 0.16854588 0.14222421 0.15950048 0.12322461 0.14544861
#  0.17952771 0.14800551]

# %%
print('the McLeod-Li test')
print(sm.stats.acorr_ljungbox(squared_resids, lags=[1, 2, 3, 4, 5, 6, 7, 8]))
res_2 = ARIMA(endog=squared_resids, order=(4, 0, 0), trend='c').fit(method='innovations_mle')
hypotheses = '(ar.L1 = 0), (ar.L2 = 0), (ar.L3 = 0), (ar.L4 = 0)'
# This tests that each coefficient is jointly statistically significantly different from zero.
print(res_2.f_test(hypotheses))
for param_name, param in zip(res_2.params.index, res_2.params):
    coef = round(param, 2)
    t_stats = round(res_2.tvalues[param_name], 2)
    print(f'[{param_name}] = coef:{coef}, t_stats:{t_stats}')
# Out:
# the McLeod-Li test
#       lb_stat     lb_pvalue
# 1   46.136165  1.103133e-11
# 2   85.481012  2.741789e-19
# 3  113.516859  1.920322e-24
# 4  148.803143  3.674418e-31
# 5  169.879345  7.741861e-35
# 6  199.264794  2.720748e-40
# 7  244.066247  5.072485e-49
# 8  274.538256  1.068730e-54
# <F test: F=75.96655332029268, p=nan, df_denom=inf, df_num=4>
# [const] = coef:16.94, t_stats:4.99
# [ar.L1] = coef:0.13, t_stats:8.05
# [ar.L2] = coef:0.11, t_stats:8.0
# [ar.L3] = coef:0.08, t_stats:5.03
# [ar.L4] = coef:0.11, t_stats:6.63
# [sigma2] = coef:1343.81, t_stats:83.25

# %%
res_3 = ARIMA(endog=log_change, order=(0, 0, 1), trend='c').fit(method='innovations_mle')
print('A MA(1) conditional mean model')
for param_name, param in zip(res_3.params.index, res_3.params):
    coef = round(param, 2)
    t_stats = round(res_3.tvalues[param_name], 2)
    print(f'[{param_name}] = coef:{coef}, t_stats:{t_stats}')
model = arch.arch_model(res_3.resid, vol='GARCH', p=1, q=1)
garch_results = model.fit(disp='off', show_warning=False)
print(garch_results.summary())
# Out:
# A MA(1) conditional mean model
# [const] = coef:0.13, t_stats:0.97
# [ma.L1] = coef:0.18, t_stats:9.6
# [sigma2] = coef:17.14, t_stats:41.61
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -3796.10
# Distribution:                  Normal   AIC:                           7600.19
# Method:            Maximum Likelihood   BIC:                           7621.12
#                                         No. Observations:                 1381
# Date:                Fri, Jun 16 2023   Df Residuals:                     1380
# Time:                        22:47:29   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu         1.7030e-03      0.103  1.653e-02      0.987 [ -0.200,  0.204]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.3937      0.154      2.551  1.074e-02 [9.120e-02,  0.696]
# alpha[1]       0.0949  1.867e-02      5.083  3.708e-07 [5.832e-02,  0.132]
# beta[1]        0.8842  1.966e-02     44.985      0.000   [  0.846,  0.923]
# ==========================================================================
#
# Covariance estimator: robust

# %%
# ACF of the standardized residuals and standardlized squared residuals
garch11_std_resid = garch_results.std_resid
acf_d = acf(garch11_std_resid, nlags=8)[1:]
print('ACF of the std residuals')
print(acf_d)
acf_d = acf(garch11_std_resid**2, nlags=8)[1:]
print('ACF of the squared std residuals')
print(acf_d)
print(sm.stats.acorr_ljungbox(garch11_std_resid, lags=[4,8]))
print(sm.stats.acorr_ljungbox(garch11_std_resid**2, lags=[4,8]))
# Out:
# ACF of the std residuals
# [ 0.05529489 -0.00389774  0.04059871 -0.01441605 -0.03350124 -0.02191024
#  -0.00327688 -0.01314317]
# ACF of the squared std residuals
# [-0.0003073   0.00511316 -0.00211738 -0.00583716 -0.02512702 -0.01331425
#  -0.01228585  0.00200178]
#     lb_stat  lb_pvalue
# 4  6.825416   0.145407
# 8  9.305283   0.317201
#     lb_stat  lb_pvalue
# 4  0.089814   0.999021
# 8  1.427791   0.993843

# %%
res_ar4 = ARIMA(endog = garch11_std_resid, order=(4,0,0), trend='c').fit(method='innovations_mle')
res_ar4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              std_resid   No. Observations:                 1381
# Model:                 ARIMA(4, 0, 0)   Log Likelihood               -1953.910
# Date:                Fri, 16 Jun 2023   AIC                           3919.819
# Time:                        22:48:03   BIC                           3951.202
# Sample:                    05-22-1987   HQIC                          3931.559
#                          - 11-01-2013
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0047      0.029     -0.162      0.872      -0.062       0.053
# ar.L1          0.0567      0.027      2.107      0.035       0.004       0.109
# ar.L2         -0.0095      0.027     -0.346      0.729      -0.063       0.044
# ar.L3          0.0423      0.028      1.528      0.126      -0.012       0.097
# ar.L4         -0.0191      0.027     -0.694      0.488      -0.073       0.035
# sigma2         0.9919      0.028     35.426      0.000       0.937       1.047
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               200.49
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.97   Skew:                            -0.21
# Prob(H) (two-sided):                  0.76   Kurtosis:                         4.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
hypotheses = '(ar.L1 = 0), (ar.L2 = 0), (ar.L3 = 0), (ar.L4 = 0)'
# This tests that each coefficient is jointly statistically significantly different from zero.
print(res_ar4.f_test(hypotheses))
# Out:
# <F test: F=1.8686528634014454, p=nan, df_denom=inf, df_num=4>
