# %%
import pandas as pd
from statsmodels.tsa.ar_model import AutoReg
import matplotlib.pyplot as plt

# Load the stock price data for Apple Inc.
df = pd.read_csv('https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=AAPL&apikey=R1A10JZ8TS3877SK&datatype=csv&start_date=2010-01-01')

# Fit an AR model to the closing price
closing_price = df["close"]
model = AutoReg(closing_price, lags=1)
model_fit = model.fit()

# Get the predictions
predictions = model_fit.predict(start=len(closing_price), end=len(closing_price)+100)

# Plot the original data
plt.plot(closing_price, label='Original Data')

# Plot the predictions
plt.plot(predictions, label='AR(1) Predictions', linestyle='--')

# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend()

# Show the plot
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# Get the predictions
predictions = model_fit.predict(start=len(closing_price), end=len(closing_price)+10)

# Calculate the MSE
mse = mean_squared_error(closing_price[-10:], predictions)
print(mse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13280\3729280593.py in <module>
#       5
#       6 # Calculate the MSE
# ----> 7 mse = mean_squared_error(closing_price[-10:], predictions)
#       8 print(mse)
#
# C:\Anaconda\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     436     0.825...
#     437     """
# --> 438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439         y_true, y_pred, multioutput
#     440     )
#
# C:\Anaconda\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [10, 11]
